# %%
# import json
# import os


# # Specify the directory path
# directory_path = '/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/JSON'

# # Specify the filename
# filename = 'data.json'

# # Full path including the filename
# full_path = os.path.join(directory_path, filename)

# # Writing JSON data to a file in the specified directory
# with open(full_path, 'w') as file:
#     json.dump(data, file, indent=4)

# %%
import json
import os
import pandas as pd

# Specify the directory path
directory_path = '/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/JSON'

# Specify the filename
filename = 'data.json'

# Full path including the filename
full_path = os.path.join(directory_path, filename)

# Reading JSON data back from the file
with open(full_path, 'r') as file:
    data_loaded = json.load(file)

# Print the data to verify it's been read correctly
print(data_loaded)
# Out:
# {'bankName': 'SWEDBANK', 'categories': [{'category': 'Gambling', 'count12Months': 157, 'count3Months': 61, 'count6Months': 102, 'count9Months': 115, 'monthlyAvg': 1598, 'partOfSalary12Months': 7.3, 'partOfSalary3Months': 19.8, 'partOfSalary6Months': 13.2, 'partOfSalary9Months': 8.3, 'sum12Months': 20779, 'sum3Months': 8848, 'sum6Months': 14498, 'sum9Months': 15567}, {'category': 'Crypto', 'count12Months': 0, 'count3Months': 0, 'count6Months': 0, 'count9Months': 0, 'monthlyAvg': 0, 'partOfSalary12Months': 0, 'partOfSalary3Months': 0, 'partOfSalary6Months': 0, 'partOfSalary9Months': 0, 'sum12Months': 0, 'sum3Months': 0, 'sum6Months': 0, 'sum9Months': 0}, {'category': 'MoneyRemittance', 'count12Months': 0, 'count3Months': 0, 'count6Months': 0, 'count9Months': 0, 'monthlyAvg': 0, 'partOfSalary12Months': 0, 'partOfSalary3Months': 0, 'partOfSalary6Months': 0, 'partOfSalary9Months': 0, 'sum12Months': 0, 'sum3Months': 0, 'sum6Months': 0, 'sum9Months': 0}, {'category': 'CashWithdrawal', 'coun
# ...

# %%
pd.DataFrame(data_loaded)
# Out:
#     bankName                                         categories countryCode  \
# 0   SWEDBANK  {'category': 'Gambling', 'count12Months': 157,...          SE
# 1   SWEDBANK  {'category': 'Crypto', 'count12Months': 0, 'co...          SE
# 2   SWEDBANK  {'category': 'MoneyRemittance', 'count12Months...          SE
# 3   SWEDBANK  {'category': 'CashWithdrawal', 'count12Months'...          SE
# 4   SWEDBANK  {'category': 'Gaming', 'count12Months': 0, 'co...          SE
# 5   SWEDBANK  {'category': 'MobilePayment', 'count12Months':...          SE
# 6   SWEDBANK  {'category': 'DebtCollection', 'count12Months'...          SE
# 7   SWEDBANK  {'category': 'InstallmentPayment', 'count12Mon...          SE
# 8   SWEDBANK  {'category': 'HousingCost', 'count12Months': 1...          SE
# 9   SWEDBANK  {'category': 'DirectDebit', 'count12Months': 0...          SE
# 10  SWEDBANK  {'category': 'Unclassified', 'count12Months': ...          SE
#
#     monthCount                              reportId
# ...
