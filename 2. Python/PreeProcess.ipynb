# %%
# import json
# import os


# # Specify the directory path
# directory_path = '/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/JSON'

# # Specify the filename
# filename = 'data.json'

# # Full path including the filename
# full_path = os.path.join(directory_path, filename)

# # Writing JSON data to a file in the specified directory
# with open(full_path, 'w') as file:
#     json.dump(data, file, indent=4)

# %%
import json
import os
import pandas as pd
import numpy

# Specify the directory path
directory_path = '/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/JSON'

# Specify the filename
filename = 'data.json'

# Full path including the filename
full_path = os.path.join(directory_path, filename)

# Reading JSON data back from the file
with open(full_path, 'r') as file:
    data_loaded = json.load(file)

# Print the data to verify it's been read correctly
print(data_loaded)
# Out:
# {'bankName': 'SWEDBANK', 'categories': [{'category': 'Gambling', 'count12Months': 157, 'count3Months': 61, 'count6Months': 102, 'count9Months': 115, 'monthlyAvg': 1598, 'partOfSalary12Months': 7.3, 'partOfSalary3Months': 19.8, 'partOfSalary6Months': 13.2, 'partOfSalary9Months': 8.3, 'sum12Months': 20779, 'sum3Months': 8848, 'sum6Months': 14498, 'sum9Months': 15567}, {'category': 'Crypto', 'count12Months': 0, 'count3Months': 0, 'count6Months': 0, 'count9Months': 0, 'monthlyAvg': 0, 'partOfSalary12Months': 0, 'partOfSalary3Months': 0, 'partOfSalary6Months': 0, 'partOfSalary9Months': 0, 'sum12Months': 0, 'sum3Months': 0, 'sum6Months': 0, 'sum9Months': 0}, {'category': 'MoneyRemittance', 'count12Months': 0, 'count3Months': 0, 'count6Months': 0, 'count9Months': 0, 'monthlyAvg': 0, 'partOfSalary12Months': 0, 'partOfSalary3Months': 0, 'partOfSalary6Months': 0, 'partOfSalary9Months': 0, 'sum12Months': 0, 'sum3Months': 0, 'sum6Months': 0, 'sum9Months': 0}, {'category': 'CashWithdrawal', 'count12Months': 32, 'count3Months': 7, 'count6Months': 13, 'count9Months': 19, 'monthlyAvg': 3424, 'partOfSalary12Months': 15.6, 'partOfSalary3Months': 13.6, 'partOfSalary6Months': 13.8, 'partOfSalary9Months': 11.1, 'sum12Months': 44514, 'sum3Months': 6114, 'sum6Months': 15214, 'sum9Months': 20914}, {'category': 'Gaming', 'count12Months': 0, 'count3Months': 0, 'count6Months': 0, 'count9Months': 0, 'monthlyAvg': 0, 'partOfSalary12Months': 0, 'partOfSalary3Months': 0, 'partOfSalary6Months': 0, 'partOfSalary9Months': 0, 'sum12Months': 0, 'sum3Months': 0, 'sum6Months': 0, 'sum9Months': 0}, {'category': 'MobilePayment', 'count12Months': 87, 'count3Months': 21, 'count6Months': 48, 'count9Months': 67, 'monthlyAvg': 4703, 'partOfSalary12Months': 21.4, 'partOfSalary3Months': 27.2, 'partOfSalary6Months': 26.4, 'partOfSalary9Months': 26.9, 'sum12Months': 61149, 'sum3Months': 12186, 'sum6Months': 29069, 'sum9Months': 50493}, {'category': 'DebtCollection', 'count12Months': 2, 'count3Months': 0, 'count6Months': 0, 'count9Months': 0, 'monthlyAvg': 585, 'partOfSalary12Months': 2.7, 'partOfSalary3Months': 0, 'partOfSalary6Months': 0, 'partOfSalary9Months': 0, 'sum12Months': 7608, 'sum3Months': 0, 'sum6Months': 0, 'sum9Months': 0}, {'category': 'InstallmentPayment', 'count12Months': 68, 'count3Months': 16, 'count6Months': 33, 'count9Months': 46, 'monthlyAvg': 18709, 'partOfSalary12Months': 85, 'partOfSalary3Months': 100, 'partOfSalary6Months': 130.1, 'partOfSalary9Months': 100.1, 'sum12Months': 243223, 'sum3Months': 44796, 'sum6Months': 143165, 'sum9Months': 188001}, {'category': 'HousingCost', 'count12Months': 13, 'count3Months': 3, 'count6Months': 7, 'count9Months': 10, 'monthlyAvg': 6166, 'partOfSalary12Months': 28, 'partOfSalary3Months': 45.8, 'partOfSalary6Months': 37.2, 'partOfSalary9Months': 32.5, 'sum12Months': 80166, 'sum3Months': 20512, 'sum6Months': 40952, 'sum9Months': 60983}, {'category': 'DirectDebit', 'count12Months': 0, 'count3Months': 0, 'count6Months': 0, 'count9Months': 0, 'monthlyAvg': 0, 'partOfSalary12Months': 0, 'partOfSalary3Months': 0, 'partOfSalary6Months': 0, 'partOfSalary9Months': 0, 'sum12Months': 0, 'sum3Months': 0, 'sum6Months': 0, 'sum9Months': 0}, {'category': 'Unclassified', 'count12Months': 963, 'count3Months': 401, 'count6Months': 694, 'count9Months': 852, 'monthlyAvg': 13067, 'partOfSalary12Months': 59.4, 'partOfSalary3Months': 174.3, 'partOfSalary6Months': 115.7, 'partOfSalary9Months': 81.1, 'sum12Months': 169881, 'sum3Months': 78082, 'sum6Months': 127374, 'sum9Months': 152291}], 'countryCode': 'SE', 'monthCount': 14, 'reportId': '00000000-0000-0000-0000-000000000000'}

# %%
def getLightsData(data_loaded):

    play = pd.DataFrame(data_loaded)

    for i in range(len(play.categories)-1):

        
        frame =play.categories[i]

        kategori = list(play.categories[i].keys())[i]
        #print(kategori)

        # Rename keys by adding 'Gambling' prefix and exclude 'category'
        data_renamed = {f'{kategori}_{k}': v for k, v in frame.items() if k != 'category'}

        if i == 0:
            df =  pd.DataFrame([data_renamed])
        else:
            df = pd.concat([df,pd.DataFrame([data_renamed])],axis=1)

    return df

# %%
getLightsData(data_loaded)
# Out:
#    category_count12Months  category_count3Months  category_count6Months  \
# 0                     157                     61                    102
#
#    category_count9Months  category_monthlyAvg  category_partOfSalary12Months  \
# 0                    115                 1598                            7.3
#
#    category_partOfSalary3Months  category_partOfSalary6Months  \
# 0                          19.8                          13.2
#
#    category_partOfSalary9Months  category_sum12Months  ...  \
# 0                           8.3                 20779  ...
#
#    partOfSalary9Months_count9Months  partOfSalary9Months_monthlyAvg  \
# 0                                 0                               0
#
#    partOfSalary9Months_partOfSalary12Months  \
# 0                                         0
#
#    partOfSalary9Months_partOfSalary3Months  \
# 0                                        0
#
#    partOfSalary9Months_partOfSalary6Months  \
# 0                                        0
#
#    partOfSalary9Months_partOfSalary9Months  partOfSalary9Months_sum12Months  \
# 0                                        0                                0
#
#    partOfSalary9Months_sum3Months  partOfSalary9Months_sum6Months  \
# 0                               0                               0
#
#    partOfSalary9Months_sum9Months
# 0                               0
#
# [1 rows x 130 columns]

# %%
data_loaded
# Out:
# {'bankName': 'SWEDBANK',
#  'categories': [{'category': 'Gambling',
#    'count12Months': 157,
#    'count3Months': 61,
#    'count6Months': 102,
#    'count9Months': 115,
#    'monthlyAvg': 1598,
#    'partOfSalary12Months': 7.3,
#    'partOfSalary3Months': 19.8,
#    'partOfSalary6Months': 13.2,
#    'partOfSalary9Months': 8.3,
#    'sum12Months': 20779,
#    'sum3Months': 8848,
#    'sum6Months': 14498,
#    'sum9Months': 15567},
#   {'category': 'Crypto',
#    'count12Months': 0,
#    'count3Months': 0,
#    'count6Months': 0,
#    'count9Months': 0,
#    'monthlyAvg': 0,
#    'partOfSalary12Months': 0,
#    'partOfSalary3Months': 0,
#    'partOfSalary6Months': 0,
#    'partOfSalary9Months': 0,
#    'sum12Months': 0,
#    'sum3Months': 0,
#    'sum6Months': 0,
#    'sum9Months': 0},
#   {'category': 'MoneyRemittance',
#    'count12Months': 0,
#    'count3Months': 0,
#    'count6Months': 0,
#    'count9Months': 0,
#    'monthlyAvg': 0,
#    'partOfSalary12Months': 0,
#    'partOfSalary3Months': 0,
#    'partOfSalary6Months': 0,
#    'partOfSalary9Months': 0,
#    'sum12Months': 0,
#    'sum3Months': 0,
#    'sum6Months': 0,
#    'sum9Months': 0},
#   {'category': 'CashWithdrawal',
#    'count12Months': 32,
#    'count3Months': 7,
#    'count6Months': 13,
#    'count9Months': 19,
#    'monthlyAvg': 3424,
#    'partOfSalary12Months': 15.6,
#    'partOfSalary3Months': 13.6,
#    'partOfSalary6Months': 13.8,
#    'partOfSalary9Months': 11.1,
#    'sum12Months': 44514,
#    'sum3Months': 6114,
#    'sum6Months': 15214,
#    'sum9Months': 20914},
#   {'category': 'Gaming',
#    'count12Months': 0,
#    'count3Months': 0,
#    'count6Months': 0,
#    'count9Months': 0,
#    'monthlyAvg': 0,
#    'partOfSalary12Months': 0,
#    'partOfSalary3Months': 0,
#    'partOfSalary6Months': 0,
#    'partOfSalary9Months': 0,
#    'sum12Months': 0,
#    'sum3Months': 0,
#    'sum6Months': 0,
#    'sum9Months': 0},
#   {'category': 'MobilePayment',
#    'count12Months': 87,
#    'count3Months': 21,
#    'count6Months': 48,
#    'count9Months': 67,
#    'monthlyAvg': 4703,
#    'partOfSalary12Months': 21.4,
#    'partOfSalary3Months': 27.2,
#    'partOfSalary6Months': 26.4,
#    'partOfSalary9Months': 26.9,
#    'sum12Months': 61149,
#    'sum3Months': 12186,
#    'sum6Months': 29069,
#    'sum9Months': 50493},
#   {'category': 'DebtCollection',
#    'count12Months': 2,
#    'count3Months': 0,
#    'count6Months': 0,
#    'count9Months': 0,
#    'monthlyAvg': 585,
#    'partOfSalary12Months': 2.7,
#    'partOfSalary3Months': 0,
#    'partOfSalary6Months': 0,
#    'partOfSalary9Months': 0,
#    'sum12Months': 7608,
#    'sum3Months': 0,
#    'sum6Months': 0,
#    'sum9Months': 0},
#   {'category': 'InstallmentPayment',
#    'count12Months': 68,
#    'count3Months': 16,
#    'count6Months': 33,
#    'count9Months': 46,
#    'monthlyAvg': 18709,
#    'partOfSalary12Months': 85,
#    'partOfSalary3Months': 100,
#    'partOfSalary6Months': 130.1,
#    'partOfSalary9Months': 100.1,
#    'sum12Months': 243223,
#    'sum3Months': 44796,
#    'sum6Months': 143165,
#    'sum9Months': 188001},
#   {'category': 'HousingCost',
#    'count12Months': 13,
#    'count3Months': 3,
#    'count6Months': 7,
#    'count9Months': 10,
#    'monthlyAvg': 6166,
#    'partOfSalary12Months': 28,
#    'partOfSalary3Months': 45.8,
#    'partOfSalary6Months': 37.2,
#    'partOfSalary9Months': 32.5,
#    'sum12Months': 80166,
#    'sum3Months': 20512,
#    'sum6Months': 40952,
#    'sum9Months': 60983},
#   {'category': 'DirectDebit',
#    'count12Months': 0,
#    'count3Months': 0,
#    'count6Months': 0,
#    'count9Months': 0,
#    'monthlyAvg': 0,
#    'partOfSalary12Months': 0,
#    'partOfSalary3Months': 0,
#    'partOfSalary6Months': 0,
#    'partOfSalary9Months': 0,
#    'sum12Months': 0,
#    'sum3Months': 0,
#    'sum6Months': 0,
#    'sum9Months': 0},
#   {'category': 'Unclassified',
#    'count12Months': 963,
#    'count3Months': 401,
#    'count6Months': 694,
#    'count9Months': 852,
#    'monthlyAvg': 13067,
#    'partOfSalary12Months': 59.4,
#    'partOfSalary3Months': 174.3,
#    'partOfSalary6Months': 115.7,
#    'partOfSalary9Months': 81.1,
#    'sum12Months': 169881,
#    'sum3Months': 78082,
#    'sum6Months': 127374,
#    'sum9Months': 152291}],
#  'countryCode': 'SE',
#  'monthCount': 14,
#  'reportId': '00000000-0000-0000-0000-000000000000'}

# %%
## vilken rapport ska jag välja för att skicka in, VIlken gälde när vi tog kreditbeslutet

# %%
null
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/2. Python/PreeProcess.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository%20Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/2.%20Python/PreeProcess.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> null
#
# NameError: name 'null' is not defined

# %%
# import json
# import os


# # Specify the directory path
# directory_path = '/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/JSON'

# # Specify the filename
# filename = 'credit_decision.json'

# # Full path including the filename
# full_path = os.path.join(directory_path, filename)

# # Writing JSON data to a file in the specified directory
# with open(full_path, 'w') as file:
#     json.dump(credit_decision, file, indent=4)

# %%
import json
import os
import pandas as pd
import numpy

# Specify the directory path
directory_path = '/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/JSON'

# Specify the filename
filename = 'credit_decision.json'

# Full path including the filename
full_path = os.path.join(directory_path, filename)

# Reading JSON data back from the file
with open(full_path, 'r') as file:
    data_loaded = json.load(file)

# Print the data to verify it's been read correctly
print(data_loaded)
# Out:
# {'additions': [], 'decision': 'Approved', 'decision1': 'Approved', 'decision1By': 'marisol@nstart.com', 'decision1Date': '2024-01-30T15:30:04Z', 'decision2': 'None', 'decision2By': None, 'decision2Date': None, 'decisionComment1': 'Kalp OK, Score OK, Riskklass OK, Inkomst Verifierad. Beslut i enlighet med kreditinstruktionen.', 'decisionComment2': None, 'id': '09d26307-b885-4b90-866f-0982f33d1087', 'isDualityNeeded': False, 'loanApplicationId': 'daf9da15-9f66-4ea0-ae41-cf9cedde4661', 'requestedBy': 'mark@nstart.com', 'requestedComment': 'komplett', 'requestedDate': '2024-01-30T15:29:40Z'}

# %%
data_loaded
# Out:
# {'additions': [],
#  'decision': 'Approved',
#  'decision1': 'Approved',
#  'decision1By': 'marisol@nstart.com',
#  'decision1Date': '2024-01-30T15:30:04Z',
#  'decision2': 'None',
#  'decision2By': None,
#  'decision2Date': None,
#  'decisionComment1': 'Kalp OK, Score OK, Riskklass OK, Inkomst Verifierad. Beslut i enlighet med kreditinstruktionen.',
#  'decisionComment2': None,
#  'id': '09d26307-b885-4b90-866f-0982f33d1087',
#  'isDualityNeeded': False,
#  'loanApplicationId': 'daf9da15-9f66-4ea0-ae41-cf9cedde4661',
#  'requestedBy': 'mark@nstart.com',
#  'requestedComment': 'komplett',
#  'requestedDate': '2024-01-30T15:29:40Z'}

# %%
data_loaded = pd.DataFrame([data_loaded])

# %%
data_loaded
# Out:
#   additions  decision decision1         decision1By         decision1Date  \
# 0        []  Approved  Approved  marisol@nstart.com  2024-01-30T15:30:04Z
#
#   decision2 decision2By decision2Date  \
# 0      None        None          None
#
#                                     decisionComment1 decisionComment2  \
# 0  Kalp OK, Score OK, Riskklass OK, Inkomst Verif...             None
#
#                                      id  isDualityNeeded  \
# 0  09d26307-b885-4b90-866f-0982f33d1087            False
#
#                       loanApplicationId      requestedBy requestedComment  \
# 0  daf9da15-9f66-4ea0-ae41-cf9cedde4661  mark@nstart.com         komplett
#
#           requestedDate
# 0  2024-01-30T15:29:40Z

# %%
# Specify the directory path
directory_path = '/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/JSON'

# Specify the filename
filename = 'creditor_analysis.json'

# Full path including the filename
full_path = os.path.join(directory_path, filename)

# Reading JSON data back from the file
with open(full_path, 'r') as file:
    data_loaded = json.load(file)

# Print the data to verify it's been read correctly
print(data_loaded)
# Out:
# {'creditors': [{'count': 1, 'name': 'ANYFIN', 'sum': 30532}, {'count': 1, 'name': 'SVEA EKONOMI', 'sum': 203}], 'debtCollectors': [{'count': 1, 'name': 'ALEKTUM', 'sum': 462}, {'count': 1, 'name': 'COLLECTIA INKASSO', 'sum': 340}], 'installmentPayments': [{'count': 15, 'name': 'UNKNOWN', 'sum': 58262}, {'count': 12, 'name': 'ANYFIN', 'sum': 45176}, {'count': 14, 'name': 'AMERICAN EXPRESS', 'sum': 44353}, {'count': 14, 'name': 'KLARNA BANK', 'sum': 12415}, {'count': 11, 'name': 'CSN', 'sum': 8535}, {'count': 10, 'name': 'RESURS BANK', 'sum': 8166}, {'count': 2, 'name': 'SKATTEVERKET', 'sum': 1442}, {'count': 3, 'name': 'AVARDA', 'sum': 570}, {'count': 1, 'name': 'SVEA EKONOMI', 'sum': 523}, {'count': 1, 'name': 'QLIRO', 'sum': 386}, {'count': 1, 'name': 'PAYEX', 'sum': 250}]}

# %%
## prata med någon gällande dessa
data_loaded
# Out:
# {'creditors': [{'count': 1, 'name': 'ANYFIN', 'sum': 30532},
#   {'count': 1, 'name': 'SVEA EKONOMI', 'sum': 203}],
#  'debtCollectors': [{'count': 1, 'name': 'ALEKTUM', 'sum': 462},
#   {'count': 1, 'name': 'COLLECTIA INKASSO', 'sum': 340}],
#  'installmentPayments': [{'count': 15, 'name': 'UNKNOWN', 'sum': 58262},
#   {'count': 12, 'name': 'ANYFIN', 'sum': 45176},
#   {'count': 14, 'name': 'AMERICAN EXPRESS', 'sum': 44353},
#   {'count': 14, 'name': 'KLARNA BANK', 'sum': 12415},
#   {'count': 11, 'name': 'CSN', 'sum': 8535},
#   {'count': 10, 'name': 'RESURS BANK', 'sum': 8166},
#   {'count': 2, 'name': 'SKATTEVERKET', 'sum': 1442},
#   {'count': 3, 'name': 'AVARDA', 'sum': 570},
#   {'count': 1, 'name': 'SVEA EKONOMI', 'sum': 523},
#   {'count': 1, 'name': 'QLIRO', 'sum': 386},
#   {'count': 1, 'name': 'PAYEX', 'sum': 250}]}

# %% [markdown]
# gå in i krediter
#
# vad ser vi för mönster i transaktionerna, ökar de, minskar de.
#
# Modulera slut av betalning???
#
#
#
# betalningsbeternde , en betalning per månad
#
# säg att de tär 2 hitta då det normala och utgå från det och kolla om det avviker

# %% [markdown]
# ## Stoplights

# %%
# stoplights = {
#     "crypto": "Green",
#     "cryptoStatus": "Ok",
#     "foreignPayments": "Green",
#     "foreignPaymentsStatus": "Ok",
#     "gambling": "Green",
#     "gamblingStatus": "Ok",
#     "prescreen": "Green",
#     "prescreenStatus": "Accept",
#     "salary": "Green",
#     "salaryStatus": "Ok"
# }


# import json
# import os


# # Specify the directory path
# directory_path = '/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/JSON'

# # Specify the filename
# filename = 'stoplights.json'

# # Full path including the filename
# full_path = os.path.join(directory_path, filename)

# # Writing JSON data to a file in the specified directory
# with open(full_path, 'w') as file:
#     json.dump(stoplights, file, indent=4)

# %%
# Specify the directory path
directory_path = '/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/JSON'

# Specify the filename
filename = 'stoplights.json'

# Full path including the filename
full_path = os.path.join(directory_path, filename)

# Reading JSON data back from the file
with open(full_path, 'r') as file:
    data_loaded = json.load(file)

# Print the data to verify it's been read correctly
print(data_loaded)
# Out:
# {'crypto': 'Green', 'cryptoStatus': 'Ok', 'foreignPayments': 'Green', 'foreignPaymentsStatus': 'Ok', 'gambling': 'Green', 'gamblingStatus': 'Ok', 'prescreen': 'Green', 'prescreenStatus': 'Accept', 'salary': 'Green', 'salaryStatus': 'Ok'}

# %%
pd.DataFrame([data_loaded])
# Out:
#   crypto cryptoStatus foreignPayments foreignPaymentsStatus gambling  \
# 0  Green           Ok           Green                    Ok    Green
#
#   gamblingStatus prescreen prescreenStatus salary salaryStatus
# 0             Ok     Green          Accept  Green           Ok

# %% [markdown]
# ## inkomstregler

# %%
## KALP

{
    "amount": 245000,
    "coApplicant": null,
    "coAppNeeded": false,
    "costRules": [
        {
            "coApplicant": null,
            "mainApplicant": 0,
            "name": "LeasingCarCostRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 6080,
            "name": "LivingCostRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 0,
            "name": "MortgageMonthlyCostRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 9100,
            "name": "HousingCostRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 3610,
            "name": "HouseholdCostRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 4096.704999436511,
            "name": "MonthlyCostSecuredDebtsRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 925,
            "name": "TravelingCostsRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 0,
            "name": "OtherCostsRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 0,
            "name": "ChildrenCostRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 789,
            "name": "StudentLoansRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 102.08333333333334,
            "name": "NstartLoanStressRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 0,
            "name": "MonthlyCostDebtsNotRedeemedRule"
        },
        {
            "coApplicant": null,
            "mainApplicant": 5582,
            "name": "NstartLoanMonthlyCostRule"
        }
    ],
    "countryCode": "SE",
    "currencyCode": "SEK",
    "externalReferenceId": "8947849",
    "id": "a04d9a20-f06b-4d20-90c2-7f500fab5741",
    "incomeRules": [
        {
            "coApplicant": null,
            "mainApplicant": 30990,
            "name": "IncomeRule"
        }
    ],
    "interestRate": 0.2595,
    "isSameHousehold": false,
    "isCommonChildren": false,
    "kalpResults": [
        {
            "debtRatio": 0.6588146713993761,
            "debtRatioStoplight": "GREEN",
            "result": 705,
            "resultStoplight": "GREEN",
            "resultType": "MainApplicant"
        }
    ],
    "mainApplicant": {
        "age": 32,
        "alternativeIncome": 0,
        "amortizationPercentage": 0.02,
        "debtsNotRedeemed": 0,
        "housingType": "RENTED",
        "income": 30990,
        "interestRateMortgage": "LOW",
        "leasingCarCost": 0,
        "livingCost": 9100,
        "maritalStatus": "SINGLE",
        "monthlyCostLoans": 4713,
        "mortgage": 0,
        "nbrOfCars": 0,
        "nbrOfChildren": 0,
        "otherCosts": 0,
        "ssn": "199206242894",
        "studentLoans": 789,
        "ucScore": 9.5,
        "securedDebts": 203000,
        "isReducedKalp": false
    },
    "monthlyCost": 5582,
    "paybackTime": 144,
    "pdScore": 5.57134,
    "riskClass": "Unknown",
    "status": "Unprocessed"
}

# %% [markdown]
# ## Ropa på API - Get access token

# %%
import requests
from requests.auth import HTTPBasicAuth
import json

# Dina autentiseringsuppgifter
username = 'nstart-data'
password = 'H%K(xnIde4tsEEuus5VJ8n'

# Endpoint-URL
url = 'https://staging-ms.nst.art/auth/v1.0/tokens'




# Gör en förfrågan med Basic Authentication
response = requests.post(url, auth=HTTPBasicAuth(username, password))

# Kontrollera svaret
if response.status_code == 200:
    # Förfrågan lyckades, hantera svaret här
    print('Svar från API:', response.text)
else:
    # Något gick fel, skriv ut statuskoden för felsökning
    print('Fel vid anrop av API:', response.status_code)


# Konvertera strängen till en dictionary
data = json.loads(response.text)

# Extrahera värdena
access_token = data["accessToken"]
expiration_in_seconds = data["expirationInSeconds"]
refresh_token = data["refreshToken"]
valid_from = data["validFrom"]
valid_to = data["validTo"]


# Nu kan du använda dessa variabler i din kod
print("Access Token:", access_token)
print("Expiration in Seconds:", expiration_in_seconds)
print("Refresh Token:", refresh_token)
print("Valid From:", valid_from)
print("Valid To:", valid_to)
# Out:
# Svar från API: {"accessToken":"eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJuc3RhcnQtZGF0YSIsImp0aSI6ImZmNzVhNmQxLWEzOWUtNGQwYi04ODQxLTdjYmMzYWYwNDI5ZiIsIkRhdGFUZWFtIjoiVHJ1ZSIsIkJhbmsiOiJUcnVlIiwibmJmIjoxNzA5MTA4ODMyLCJleHAiOjE3MDkxMDkxMzIsImlzcyI6InN0YWdpbmctbnN0LmFydCIsImF1ZCI6InN0YWdpbmctbnN0LmFydCJ9.Mek1tKJcFYCk4E5j1u9gDu8lfUz7lODwavuVsPG-oxzzIvseWsZvGqp1HK6Jjbg9Icui7uVCUt0PypUFRd8m8g","expirationInSeconds":300,"refreshToken":null,"validFrom":"2024-02-28T08:27:12Z","validTo":"2024-02-28T08:32:12Z"}

# %%
# Out:
# Access Token: eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJuc3RhcnQtZGF0YSIsImp0aSI6IjgxMjliZmY4LWQzMzktNGNlMi05OTYzLTA3MGMyZDJjZTY3NSIsIkRhdGFUZWFtIjoiVHJ1ZSIsIkJhbmsiOiJUcnVlIiwibmJmIjoxNzA5MTA4MzYyLCJleHAiOjE3MDkxMDg2NjIsImlzcyI6InN0YWdpbmctbnN0LmFydCIsImF1ZCI6InN0YWdpbmctbnN0LmFydCJ9.cZDLZVTm6mzgnqtMLo7WRVgWqZirGV780GVoey1F5GG0ShXYWJDjGs_0Rng4wxcGETz6g3zjRaqsxE2qrscXgA
# Expiration in Seconds: 300
# Refresh Token: None
# Valid From: 2024-02-28T08:19:22Z
# Valid To: 2024-02-28T08:24:22Z

# %% [markdown]
# ## Just example

# %%
# URL you want to make a GET request to
url = 'https://staging-ms.nst.art/bank/v1.0/categories'


# Headers including the Authorization field with Bearer token
headers = {
    'Authorization': f'Bearer {access_token}'
}

# Making a GET request with the headers
response = requests.get(url, headers=headers)

# Checking if the request was successful
if response.status_code == 200:
    # Request was successful, print the response text (or process it)
    print("Response data:", response.json())  # Using .json() to print the response data as JSON
else:
    # There was an error with the request
    print("Error:", response.status_code)
# Out:
# Response data: {'categories': [{'id': 0, 'name': 'Unclassified'}, {'id': 1, 'name': 'MobilePayment'}, {'id': 2, 'name': 'Salary'}, {'id': 3, 'name': 'HousingCost'}, {'id': 4, 'name': 'Gambling'}, {'id': 5, 'name': 'MoneyRemittance'}, {'id': 6, 'name': 'DebtCollection'}, {'id': 7, 'name': 'DirectDebit'}, {'id': 8, 'name': 'Loan'}, {'id': 9, 'name': 'OtherIncome'}, {'id': 10, 'name': 'PassiveIncome'}, {'id': 11, 'name': 'Deposit'}, {'id': 12, 'name': 'InstallmentPayment'}, {'id': 13, 'name': 'CashWithdrawal'}, {'id': 14, 'name': 'Crypto'}, {'id': 15, 'name': 'Gaming'}, {'id': 16, 'name': 'InternalTransfer'}, {'id': 17, 'name': 'OtherSubsidies'}]}

# %%
# URL you want to make a GET request to
url = 'https://staging-ms.nst.art/bank/v1.0/psd2/reports'


# Headers including the Authorization field with Bearer token
headers = {
    'Authorization': f'Bearer {access_token}'
}

# Making a GET request with the headers
response = requests.get(url, headers=headers)

# Checking if the request was successful
if response.status_code == 200:
    # Request was successful, print the response text (or process it)
    print("Response data:", response.json())  # Using .json() to print the response data as JSON
else:
    # There was an error with the request
    print("Error:", response.status_code)

# %%
/psd2/reports 

räknar utt allt





## Produkttyp --> Refinacing

# %% [markdown]
# ## STOPLIGHT V2 är den jag ska ha

# %%
# import os
# path = "/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/2. Python/Classes"
# os.chdir(path)

# from Preprocessing_Application_N import DataPreprocessor


# server = 'reporting-db.nystartfinans.net'
# database = 'reporting-db'
# username = 'Andreas'
# password = 'nCq8Sg@1lYnd(E'
# driver = '{ODBC Driver 17 for SQL Server}'  # This is an example for SQL Server, adjust according to your database and installed ODBC driver


# # Initialize DataPreprocessor with all required parameters, including the driver
# processor = DataPreprocessor(server, database, username, password, driver)


# path = "/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/1. Data/TinkReport.sql"


# df = processor.fetch_data_from_sql(path)

# %%
import requests
from requests.auth import HTTPBasicAuth
import json
import os
import pandas as pd
import numpy

# Dina autentiseringsuppgifter
username = 'nstart-data'
password = 'H%K(xnIde4tsEEuus5VJ8n'

# Endpoint-URL
url = 'https://staging-ms.nst.art/auth/v1.0/tokens'




# Gör en förfrågan med Basic Authentication
response = requests.post(url, auth=HTTPBasicAuth(username, password))

# Kontrollera svaret
if response.status_code == 200:
    # Förfrågan lyckades, hantera svaret här
    print('Svar från API:', response.text)
else:
    # Något gick fel, skriv ut statuskoden för felsökning
    print('Fel vid anrop av API:', response.status_code)


# Konvertera strängen till en dictionary
data = json.loads(response.text)

# Extrahera värdena
access_token = data["accessToken"]
expiration_in_seconds = data["expirationInSeconds"]
refresh_token = data["refreshToken"]
valid_from = data["validFrom"]
valid_to = data["validTo"]


# Nu kan du använda dessa variabler i din kod
print("Access Token:", access_token)
print("Expiration in Seconds:", expiration_in_seconds)
print("Refresh Token:", refresh_token)
print("Valid From:", valid_from)
print("Valid To:", valid_to)







# Specify the directory path
directory_path = '/Users/andreasnilsson/Library/CloudStorage/OneDrive-Nstart/Skrivbordet/Repository Homes/PSD2-Data-Engineering-Modeling-DATA-258-1/JSON'

# Specify the filename
filename = 'all.json'

# Full path including the filename
full_path = os.path.join(directory_path, filename)

# Reading JSON data back from the file
with open(full_path, 'r') as file:
    data_loaded = json.load(file)

# Print the data to verify it's been read correctly
print(data_loaded)
# Out:
# /Users/andreasnilsson/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Svar från API: {"accessToken":"eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJuc3RhcnQtZGF0YSIsImp0aSI6IjVkZGM3MTkzLWUxMDUtNDM5Yy1hY2Q2LTAwODFjZTRlMWI0NSIsIkRhdGFUZWFtIjoiVHJ1ZSIsIkJhbmsiOiJUcnVlIiwibmJmIjoxNzA5MTA5OTYxLCJleHAiOjE3MDkxMTAyNjEsImlzcyI6InN0YWdpbmctbnN0LmFydCIsImF1ZCI6InN0YWdpbmctbnN0LmFydCJ9.b_oAQm43XUpQVCtvVotzCGqR9bd91QGBBZwXlhtWw5ncv9ZLcqtCcVAe3ZM65VUc13g6vv8rJ9fr6P0trU5q4A","expirationInSeconds":300,"refreshToken":null,"validFrom":"2024-02-28T08:46:02Z","validTo":"2024-02-28T08:51:02Z"}
# Access Token: eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJuc3RhcnQtZGF0YSIsImp0aSI6IjVkZGM3MTkzLWUxMDUtNDM5Yy1hY2Q2LTAwODFjZTRlMWI0NSIsIkRhdGFUZWFtIjoiVHJ1ZSIsIkJhbmsiOiJUcnVlIiwibmJmIjoxNzA5MTA5OTYxLCJleHAiOjE3MDkxMTAyNjEsImlzcyI6InN0YWdpbmctbnN0LmFydCIsImF1ZCI6InN0YWdpbmctbnN0LmFydCJ9.b_oAQm43XUpQVCtvVotzCGqR9bd91QGBBZwXlhtWw5ncv9ZLcqtCcVAe3ZM65VUc13g6vv8rJ9fr6P0trU5q4A
# Expiration in Seconds: 300
# Refresh Token: None
# Valid From: 2024-02-28T08:46:02Z
# Valid To: 2024-02-28T08:51:02Z
# {'accounts': [{'balances': {'available': None, 'booked': {'currencyCode': None, 'value': None}}, 'customerSegment': 'PERSONAL', 'dates': {'lastRefreshed': '2024-02-27T09:31:22Z'}, 'financialInstitutionId': 'ea3b5ac45e274e62b3fd1181aa3aca9c', 'id': 'bf0b136a6fb44959a3394659180e2074', 'identifiers': {'financialInstitution': {'accountNumber': '6501-145 069 508'}, 'iban': {'bban': '60000000000145069508', 'bic': None, 'iban': 'SE2560000000000145069508'}}, 'name': 'Mitt sparkonto', 'type': 'CHECKING'}, {'balances': {'available': None, 'booked': {'currencyCode': None, 'value': None}}, 'customerSegment': 'PERSONAL', 'dates': {'lastRefreshed': '2024-02-27T09:31:22Z'}, 'financialInstitutionId': 'ea3b5ac45e274e62b3fd1181aa3aca9c', 'id': '8b4c68d7182942e3828bf3bae06c1767', 'identifiers': {'financialInstitution': {'accountNumber': '6501-282 522 212'}, 'iban': {'bban': '60000000000282522212', 'bic': None, 'iban': 'SE2460000000000282522212'}}, 'name': 'Lön', 'type': 'CHECKING'}], 'id': 'ac97447a4cc94aa5a418c9277aa9c37e', 'transactions': [{'accountId': '8b4c68d7182942e3828bf3bae06c1767', 'amount': {'currencyCode': 'SEK', 'value': {'scale': '1', 'unscaledValue': '-8500'}}, 'dates': {'booked': '2024-02-27', 'value': None}, 'descriptions': {'display': 'Trygghetsför', 'original': 'Trygghetsför'}, 'id': '6c3c61ae8e064ec1aae4fb1265b4c5b8', 'identifiers': None, 'providerMutability': 'MUTABILITY_UNDEFINED', 'status': 'BOOKED', 'types': {'financialInstitutionTypeCode': None, 'type': 'DEFAULT'}}, {'accountId': '8b4c68d7182942e3828bf3bae06c1767', 'amount': {'currencyCode': 'SEK', 'value': {'scale': '1', 'unscaledValue': '-420'}}, 'dates': {'booked': '2024-02-26', 'value': None}, 'descriptions': {'display': 'Sl', 'original': 'SL'}, 'id': '0ec8b530ff614df69946ede0eb0701e4', 'identifiers': None, 'providerMutability': 'MUTABILITY_UNDEFINED', 'status': 'BOOKED', 'types': {'financialInstitutionTypeCode': None, 'type': 'DEFAULT'}}, {'accountId': '8b4c68d7182942e3828bf3bae06c1767', 'amount': {'currencyCode': 'SEK', 'value': {'scale': '1', 'unscaledValue': '-17680'}}, 'dates': {'booked': '2024-02-26', 'value': None}, 'descriptions': {'display': 'Hi3g', 'original': 'HI3G'}, 'id': '18e55bfe37f24fcdaa07362727c8afbb', 'identifiers': None, 'providerMutability': 'MUTABILITY_UNDEFINED', 'status': 'BOOKED', 'types': {'financialInstitutionTypeCode': None, 'type': 'DEFAULT'}}, {'accountId': '8b4c68d7182942e3828bf3bae06c1767', 'amount': {'currencyCode': 'SEK', 'value': {'scale': '1', 'unscaledValue': '-100'}}, 'dates': {'booked': '2024-02-26', 'value': None}, 'descriptions': {'display': 'Centralens Toa', 'original': 'CENTRALENS TOA'}, 'id': '18e6cf5d671246e5971663cbf80ba905', 'identifiers': None, 'providerMutability': 'MUTABILITY_UNDEFINED', 'status': 'BOOKED', 'types': {'financialInstitutionTypeCode': None, 'type': 'DEFAULT'}}, {'accountId': '8b4c68d7182942e3828bf3bae06c1767', 'amount': {'currencyCode': 'SEK', 'value': {'scale': '1', 'unscaledValue': '-10752'}}, 'dates': {'booked': '2024-02-26', 'value': None}, 'descriptions': {'display': 'Qliro', 'original': 'Qliro'}, 'id': '1b7dde5c865349239337efeb973be232', 'identifiers': None, 'providerMutability': 'MUTABILITY_UNDEFINED', 'status': 'BOOKED', 'types': {'financialInstitutionTypeCode': None, 'type': 'DEFAULT'}}, {'accountId': '8b4c68d7182942e3828bf3bae06c1767', 'amount': {'currencyCode': 'SEK', 'value': {'scale': '1', 'unscaledValue': '-4315'}}, 'dates': {'booked': '2024-02-26', 'value': None}, 'descriptions': {'display': 'Walley', 'original': 'WALLEY'}, 'id': '2c87fc398e2f451bbdec1e6c613f8fe6', 'identifiers': None, 'providerMutability': 'MUTABILITY_UNDEFINED', 'status': 'BOOKED', 'types': {'financialInstitutionTypeCode': None, 'type': 'DEFAULT'}}, {'accountId': '8b4c68d7182942e3828bf3bae06c1767', 'amount': {'currencyCode': 'SEK', 'value': {'scale': '1', 'unscaledValue': '-45100'}}, 'dates': {'booked': '2024-02-26', 'value': None}, 'descriptions': {'display': 'Collector-L', 'original': 'Collector-L'}, 'id': '3607683802d7 ...

# %%
import json


# URL you want to make a GET request to
url = 'https://staging-ms.nst.art/bank/v1.0/prescreen/reports'


# Headers including the Authorization field with Bearer token
headers = {
    'Authorization': f'Bearer {access_token}',
    'Content-Type': 'application/json'
}

json = {
    'countryCode': 'SE',
    'productType': 'Refinancing',
    'psd2': json.dumps(data_loaded)
}

# Making a GET request with the headers
response = requests.post(url, headers=headers, json=json)

# Checking if the request was successful
if response.status_code == 200:
    # Request was successful, print the response text (or process it)
    print("Response data:", response.json())  # Using .json() to print the response data as JSON
else:
    # There was an error with the request
    print("Error:", response.status_code)
    print("Response data:", response.json())
# Out:
# Response data: {'categoryAnalysis': [{'avg': 24294, 'avg3Months': 24363, 'avg6Months': 24105, 'category': 'Salary', 'count': 8, 'currencyCode': 'SEK', 'distribution': [['2023-07-31T23:59:59Z', 25427], ['2023-08-31T23:59:59Z', 22033], ['2023-09-30T23:59:59Z', 20563], ['2023-10-31T23:59:59Z', 28948], ['2023-11-30T23:59:59Z', 24227], ['2023-12-31T23:59:59Z', 22930], ['2024-01-31T23:59:59Z', 25933]], 'forecast': 25291, 'sum': 170061, 'trend': 2.2}, {'avg': 780, 'avg3Months': 0, 'avg6Months': 780, 'category': 'PassiveIncome', 'count': 1, 'currencyCode': 'SEK', 'distribution': [['2023-07-31T23:59:59Z', 0], ['2023-08-31T23:59:59Z', 0], ['2023-09-30T23:59:59Z', 0], ['2023-10-31T23:59:59Z', 780], ['2023-11-30T23:59:59Z', 0], ['2023-12-31T23:59:59Z', 0], ['2024-01-31T23:59:59Z', 0]], 'forecast': 111, 'sum': 780, 'trend': -100.0}, {'avg': 0, 'avg3Months': 0, 'avg6Months': 0, 'category': 'OtherIncome', 'count': 0, 'currencyCode': 'SEK', 'distribution': [['2023-07-31T23:59:59Z', 0], ['2023-08-31T23:59:59Z', 0], ['2023-09-30T23:59:59Z', 0], ['2023-10-31T23:59:59Z', 0], ['2023-11-30T23:59:59Z', 0], ['2023-12-31T23:59:59Z', 0], ['2024-01-31T23:59:59Z', 0]], 'forecast': 0, 'sum': 0, 'trend': 0.0}, {'avg': 301, 'avg3Months': 251, 'avg6Months': 316, 'category': 'Gambling', 'count': 20, 'currencyCode': 'SEK', 'distribution': [['2023-07-27T23:59:59Z', 136], ['2023-08-27T23:59:59Z', 372], ['2023-09-27T23:59:59Z', 472], ['2023-10-27T23:59:59Z', 540], ['2023-11-27T23:59:59Z', 136], ['2023-12-27T23:59:59Z', 295], ['2024-01-27T23:59:59Z', 50], ['2024-02-27T23:59:59Z', 408]], 'forecast': 266, 'sum': 2409, 'trend': -34.4}, {'avg': 0, 'avg3Months': 0, 'avg6Months': 0, 'category': 'Crypto', 'count': 0, 'currencyCode': 'SEK', 'distribution': [['2023-07-27T23:59:59Z', 0], ['2023-08-27T23:59:59Z', 0], ['2023-09-27T23:59:59Z', 0], ['2023-10-27T23:59:59Z', 0], ['2023-11-27T23:59:59Z', 0], ['2023-12-27T23:59:59Z', 0], ['2024-01-27T23:59:59Z', 0], ['2024-02-27T23:59:59Z', 0]], 'forecast': 0, 'sum': 0, 'trend': 0.0}, {'avg': 0, 'avg3Months': 0, 'avg6Months': 0, 'category': 'MoneyRemittance', 'count': 0, 'currencyCode': 'SEK', 'distribution': [['2023-07-27T23:59:59Z', 0], ['2023-08-27T23:59:59Z', 0], ['2023-09-27T23:59:59Z', 0], ['2023-10-27T23:59:59Z', 0], ['2023-11-27T23:59:59Z', 0], ['2023-12-27T23:59:59Z', 0], ['2024-01-27T23:59:59Z', 0], ['2024-02-27T23:59:59Z', 0]], 'forecast': 0, 'sum': 0, 'trend': 0.0}, {'avg': 1812, 'avg3Months': 1833, 'avg6Months': 2416, 'category': 'CashWithdrawal', 'count': 8, 'currencyCode': 'SEK', 'distribution': [['2023-07-27T23:59:59Z', 0], ['2023-08-27T23:59:59Z', 0], ['2023-09-27T23:59:59Z', 4500], ['2023-10-27T23:59:59Z', 4000], ['2023-11-27T23:59:59Z', 500], ['2023-12-27T23:59:59Z', 0], ['2024-01-27T23:59:59Z', 0], ['2024-02-27T23:59:59Z', 5500]], 'forecast': 2964, 'sum': 14500, 'trend': -38.9}, {'avg': 37, 'avg3Months': 39, 'avg6Months': 39, 'category': 'Gaming', 'count': 8, 'currencyCode': 'SEK', 'distribution': [['2023-07-27T23:59:59Z', 29], ['2023-08-27T23:59:59Z', 39], ['2023-09-27T23:59:59Z', 39], ['2023-10-27T23:59:59Z', 39], ['2023-11-27T23:59:59Z', 39], ['2023-12-27T23:59:59Z', 39], ['2024-01-27T23:59:59Z', 39], ['2024-02-27T23:59:59Z', 39]], 'forecast': 41, 'sum': 302, 'trend': 0.0}, {'avg': 0, 'avg3Months': 0, 'avg6Months': 0, 'category': 'MobilePayment', 'count': 0, 'currencyCode': 'SEK', 'distribution': [['2023-07-27T23:59:59Z', 0], ['2023-08-27T23:59:59Z', 0], ['2023-09-27T23:59:59Z', 0], ['2023-10-27T23:59:59Z', 0], ['2023-11-27T23:59:59Z', 0], ['2023-12-27T23:59:59Z', 0], ['2024-01-27T23:59:59Z', 0], ['2024-02-27T23:59:59Z', 0]], 'forecast': 0, 'sum': 0, 'trend': 0.0}, {'avg': 0, 'avg3Months': 0, 'avg6Months': 0, 'category': 'DebtCollection', 'count': 0, 'currencyCode': 'SEK', 'distribution': [['2023-07-27T23:59:59Z', 0], ['2023-08-27T23:59:59Z', 0], ['2023-09-27T23:59:59Z', 0], ['2023-10-27T23:59:59Z', 0], ['2023-11-27T23:59:59Z', 0], ['2023-12-27T23:59:59Z', 0], ['2024-01-27T23:59:59Z', 0], ['2024-02-27T23:59:5 ...

# %%
# tink rapporten

# 1. 
# account/ transaktioner

# JSON format

# men gör det till en sträng innan och skicka i psd2 property

# %%
# SELECT TOP (1000) [AccountJsonID]
#       ,[TransactionJsonID]
#       ,[ReportDate]
#       ,[SSN]
#       ,[AccountJSON]
#       ,[TransactionJSON]
#       ,[CheckID]
#       ,[QueryString]
#   FROM [nim-prod].[tink].[TinkReports]

#   where SSN = '199202223989'

# %% [markdown]
# 1. UC term --> balco borgen  History
#
# 2.
